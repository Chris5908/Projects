# %%
# %pwd
# Out:
# '/Users/christophepere/Autobiz/Prototype_Hadoop_Spark/Scripts'

# %%
# %matplotlib inline
from statsmodels.tsa.arima_model import ARIMA
import pandas as pd 
from pandas import Series
import numpy as np
import matplotlib, matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
matplotlib.style.use("ggplot")

# %%
df = Series.from_csv('../../../Downloads/monthly-car-sales-in-quebec-1960.csv', sep=';', header=0)

# %%
print(df.head())
# Out:
# Month
# 1960-01     6550.0
# 1960-02     8728.0
# 1960-03    12026.0
# 1960-04    14395.0
# 1960-05    14587.0
# Name: Monthly car sales in Quebec 1960-1968, dtype: float64

# %%
df.plot()

# %%
differenced = df.diff(12)

# %%
differenced = differenced[12:]

# %%
differenced.plot()

# %%
plot_acf(differenced)
